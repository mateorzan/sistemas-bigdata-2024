# %% [markdown]
# # XLS and XLSX files.
#
# Pandas documentation: https://pandas.pydata.org/docs/index.html
#
# Pandas API reference: https://pandas.pydata.org/docs/reference/index.html#api

# %%
# import pandas library
import pandas as pd

# %% [markdown]
# ### Educational facilities in Galicia
#
# **Source**: Portal Open Data abert@s - Xunta de Galicia
#
# https://abertos.xunta.gal/catalogo/ensino-formacion/-/dataset/0257/centros-educativos-galicia

# %%
# Sample dataset in XLS format built from educational facilities data in Galicia
# (only Coruña and Lugo)

df = pd.read_excel('../datasets/centros_educativos_galicia.xls')

# %%
# Another way of opening files and load data into a new dataframe
ficheiro = '../datasets/centros_educativos_galicia.xls'
df = pd.read_excel(ficheiro)

# %%
# show the dataframe
df
# Out:
#        Código                             Nome  \
# 0    15000016      CEIP Plurilingüe San Marcos
# 1    15000107                      CEIP A Maía
# 2    15000132             CPR Plurilingüe Alca
# 3    15000338                  CPI As Mirandas
# 4    15000363            CEIP Ponte dos Brozos
# ..        ...                              ...
# 611  15033198  CRA de Coristanco - Santa Comba
# 612  15033204          CEDA Profesional Druida
# 613  15033216          CPREX Semente Trasancos
# 614  15033228                CEIP Novo Mesoiro
# 615  15033231          EMUSPR Rockschoolcenter
#
#                                  Enderezo    Concello Provincia  Cód. postal  \
# 0                      Campo da Feira s/n    Abegondo  A Coruña        15318
# 1        Rúa Peregrina, s/n (Bertamiráns)        Ames  A Coruña        15220
# 2              Lugar Biduído de Arriba 36        Ames  A Coruña        15895
# 3         Avenida Celso Emilio Ferreiro 4        Ares  A Coruña        15624
# 4    Avenida Arsenio Iglesias, 34 (Sabon)     Arteixo  A Coruña        15142
# ..                                    ...         ...       ...          ...
# 611                    Lugar Esfarrapa 52  Coristanco  A Coruña        15147
# 612          Rúa Fernando Macías 26 Baixo    A Coruña  A Coruña        15004
# 613                        Aldea Roxal 36        Neda  A Coruña        15510
# 614                Rúa Fragas do Eume s/n    A Coruña  A Coruña        15190
# 615                            Rúa Neda 2       Narón  A Coruña        15570
#
#       Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# 0    881880201           CEIP     43.229183     -8.286580      Pública
# 1    881866002           CEIP     42.867485     -8.657342      Pública
# 2    981531103            CPR     42.846325     -8.600729      Privada
# 3    881930020            CPI     43.429363     -8.246173      Pública
# 4    881960506           CEIP     43.306940     -8.510333      Pública
# ..         ...            ...           ...           ...          ...
# 611  881880552            CRA     43.181217     -8.747868      Pública
# 612        NaN           CEDA     43.366430     -8.413181      Privada
# 613  717779077          CPREX     43.496060     -8.123106      Privada
# 614  881961235           CEIP     43.324470     -8.439917      Pública
# 615        NaN         EMUSPR     43.490913     -8.201881      Privada
#
#     ENSINO_CONCERTADO DEPENDENTE
# 0                 Non         Si
# 1                 Non         Si
# 2                  Si        Non
# 3                 Non         Si
# 4                 Non         Si
# ..                ...        ...
# 611               Non         Si
# 612               Non        Non
# 613               Non        Non
# 614               Non         Si
# 615               Non        Non
#
# [616 rows x 13 columns]

# %%
# some functions to learn about the dataframe
#df.head()
#df.tail()
#df.describe()
df.sample()
# Out:
#       Código                    Nome                    Enderezo  Concello  \
# 95  15005579  IES Plurilingüe Elviña  Rúa San José de Calasanz 6  A Coruña
#
#    Provincia  Cód. postal   Teléfono Tipo de centro  COORDENADA_X  \
# 95  A Coruña        15008  881961061            IES     43.345146
#
#     COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 95     -8.410672      Pública               Non         Si

# %%
# info about column data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Código             616 non-null    int64
#  1   Nome               616 non-null    object
#  2   Enderezo           616 non-null    object
#  3   Concello           616 non-null    object
#  4   Provincia          616 non-null    object
#  5   Cód. postal        616 non-null    int64
#  6   Teléfono           585 non-null    object
#  7   Tipo de centro     616 non-null    object
#  8   COORDENADA_X       616 non-null    float64
#  9   COORDENADA_Y       616 non-null    float64
#  10  TITULARIDADE       616 non-null    object
#  11  ENSINO_CONCERTADO  616 non-null    object
#  12  DEPENDENTE         616 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 62.7+ KB

# %%
# show column names
df.columns
# Out:
# Index(['Código', 'Nome', 'Enderezo', 'Concello', 'Provincia', 'Cód. postal',
#        'Teléfono', 'Tipo de centro', 'COORDENADA_X', 'COORDENADA_Y',
#        'TITULARIDADE', 'ENSINO_CONCERTADO', 'DEPENDENTE'],
#       dtype='object')

# %%
# Select some random names
df.Nome.sample(5)
# Out:
# 10               CPI de Cruz do Sar
# 460               CEIP das Fontiñas
# 470        CEE Manuel López Navalón
# 140                   IES de Melide
# 433    CMUS Profesional de Carballo
# Name: Nome, dtype: object

# %%
# Select municipality name and coordenates: first 10
df[['Concello','COORDENADA_X','COORDENADA_Y']].head(10)
# Out:
#    Concello  COORDENADA_X  COORDENADA_Y
# 0  Abegondo     43.229183     -8.286580
# 1      Ames     42.867485     -8.657342
# 2      Ames     42.846325     -8.600729
# 3      Ares     43.429363     -8.246173
# 4   Arteixo     43.306940     -8.510333
# 5  A Coruña     43.354420     -8.400640
# 6   Arteixo     43.345356     -8.447119
# 7     Arzúa     42.926342     -8.164634
# 8     Arzúa     42.929714     -8.157230
# 9  Bergondo     43.309380     -8.278413

# %%
# Select a column
df.Concello
# Note the type!!! <- Series
#df.Concello.unique()
# Note the type!!! <- array

# Look for the unique function in Pandas API reference
# Out:
# 0        Abegondo
# 1            Ames
# 2            Ames
# 3            Ares
# 4         Arteixo
#           ...
# 611    Coristanco
# 612      A Coruña
# 613          Neda
# 614      A Coruña
# 615         Narón
# Name: Concello, Length: 616, dtype: object

# %%
# Count elements
# Counting the elements of a series is not the same as counting the elements of an array.

#df.Concello.count()
#len(df.Concello.unique())

# %%
# Assign columns to new variables (Series)
concellos = df.Concello
concellos
# Out:
# 0        Abegondo
# 1            Ames
# 2            Ames
# 3            Ares
# 4         Arteixo
#           ...
# 611    Coristanco
# 612      A Coruña
# 613          Neda
# 614      A Coruña
# 615         Narón
# Name: Concello, Length: 616, dtype: object

# %%
# Apply conditions to Series
df.Concello == 'Ames'
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# Name: Concello, Length: 616, dtype: bool

# %%
# Select rows by their index
#df.iloc[[0,1,3,5]]
df.loc[[0,1,3,5]]
# Out:
#      Código                         Nome                          Enderezo  \
# 0  15000016  CEIP Plurilingüe San Marcos                Campo da Feira s/n
# 1  15000107                  CEIP A Maía  Rúa Peregrina, s/n (Bertamiráns)
# 3  15000338              CPI As Mirandas   Avenida Celso Emilio Ferreiro 4
# 5  15000545         EMUSPR Presto Vivace                 Rúa Posse, 37, 1º
#
#    Concello Provincia  Cód. postal   Teléfono Tipo de centro  COORDENADA_X  \
# 0  Abegondo  A Coruña        15318  881880201           CEIP     43.229183
# 1      Ames  A Coruña        15220  881866002           CEIP     42.867485
# 3      Ares  A Coruña        15624  881930020            CPI     43.429363
# 5  A Coruña  A Coruña        15009  981131545         EMUSPR     43.354420
#
#    COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 0     -8.286580      Pública               Non         Si
# 1     -8.657342      Pública               Non         Si
# 3     -8.246173      Pública               Non         Si
# 5     -8.400640      Privada               Non        Non

# %%
# Select the rows that meet a condition
df[df.Concello == 'Ames']
# Out:
#        Código                       Nome  \
# 1    15000107                CEIP A Maía
# 2    15000132       CPR Plurilingüe Alca
# 269  15019542              EEI da Igrexa
# 279  15020659               EEI de Covas
# 386  15025220  CEP Plurilingüe de Ventín
# 430  15026637            CEIP de Barouta
# 485  15027721    IES Plurilingüe de Ames
# 526  15032224        CEMU Elemental Alca
# 558  15032625         CEIP Agro do Muíño
# 560  15032649          EEI do Milladoiro
# 575  15032807          IES do Milladoiro
# 603  15033113     ESMU Municipal de Ames
#
#                                               Enderezo Concello Provincia  \
# 1                     Rúa Peregrina, s/n (Bertamiráns)     Ames  A Coruña
# 2                           Lugar Biduído de Arriba 36     Ames  A Coruña
# 269                                        A Tarroeira     Ames  A Coruña
# 279                                          Covas s/n     Ames  A Coruña
# 386                                             Ventin     Ames  A Coruña
# 430                                    Ames (San Tomé)     Ames  A Coruña
# 485                   Rúa Peregrina, s/n (Bertamirans)     Ames  A Coruña
# 526                         Lugar Biduído de Arriba 36     Ames  A Coruña
# 558                                Lugar As Cortes s/n     Ames  A Coruña
# 560                  Travesa do Porto (Milladoiro) s/n     Ames  A Coruña
# 575            Rúa Paseo da Igualdade (O Milladoiro) 5     Ames  A Coruña
# 603  Rúa Costaneira (Urbanización Aldea Nova, edifi...     Ames  A Coruña
#
#      Cód. postal   Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y  \
# 1          15220  881866002           CEIP     42.867485     -8.657342
# 2          15895  981531103            CPR     42.846325     -8.600729
# 269        15034  981884459            EEI     42.852960     -8.638422
# 279        15864  981884850            EEI     42.879627     -8.643236
# 386        15895  881867490            CEP     42.850870     -8.588841
# 430        15229  881867455           CEIP     42.910310     -8.654732
# 485        15220  881866729            IES     42.868120     -8.658323
# 526        15895  981531103           CEMU     42.846436     -8.600529
# 558        15228  881866010           CEIP     42.843860     -8.642227
# 560        15895  881866037            EEI     42.846770     -8.579979
# 575        15895  881867863            IES     42.845753     -8.582285
# 603        15220        NaN           ESMU     42.869995     -8.629151
#
#     TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 1        Pública               Non         Si
# 2        Privada                Si        Non
# 269      Pública               Non         Si
# 279      Pública               Non         Si
# 386      Pública               Non         Si
# 430      Pública               Non         Si
# 485      Pública               Non         Si
# 526      Privada               Non        Non
# 558      Pública               Non         Si
# 560      Pública               Non         Si
# 575      Pública               Non         Si
# 603      Pública               Non        Non

# %%
# Select the centers with type IES ('Tipo de centro')
serie_indices = df['Tipo de centro'] == 'IES'
df[serie_indices]
# Out:
#        Código                  Nome                                 Enderezo  \
# 13   15001136  IES Francisco Aguiar                     Avenida Da Coruña 15
# 14   15001148        IES As Mariñas                    Avenida da Coruña s/n
# 33   15002581    IES Alfredo Brañas                Rúa Vila de Corcubión s/n
# 34   15002591        IES Monte Neme                           Rúa Nacente 29
# 41   15003212    IES Agra de Raíces             Rúa Buenaventura Castro Rial
# ..        ...                   ...                                      ...
# 520  15032145      IES de Pastoriza          Rúa do Lagarto, esq. Furoca s/n
# 562  15032662       IES O Mosteirón                         Rúa Esperela S/N
# 575  15032807     IES do Milladoiro  Rúa Paseo da Igualdade (O Milladoiro) 5
# 585  15032923         IES de Carral                      Costa do Pincho s/n
# 586  15032935     IES Rego de Trabe                         Avenida de Rutis
#
#       Concello Provincia  Cód. postal   Teléfono Tipo de centro  COORDENADA_X  \
# 13    Betanzos  A Coruña        15300  881960165            IES     43.282490
# 14    Betanzos  A Coruña        15300  881880254            IES     43.283478
# 33    Carballo  A Coruña        15100  981700911            IES     43.217155
# 34    Carballo  A Coruña        15106  881960050            IES     43.212290
# 41         Cee  A Coruña        15270  881880486            IES     42.957993
# ..         ...       ...          ...        ...            ...           ...
# 520    Arteixo  A Coruña        15140  981647517            IES     43.333690
# 562       Sada  A Coruña        15168  881880949            IES     43.349600
# 575       Ames  A Coruña        15895  881867863            IES     42.845753
# 585     Carral  A Coruña        15175  881960480            IES     43.180490
# 586  Culleredo  A Coruña        15174  881960801            IES     43.312843
#
#      COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 13      -8.217094      Pública               Non         Si
# 14      -8.215625      Pública               Non         Si
# 33      -8.685111      Pública               Non         Si
# 34      -8.704391      Pública               Non         Si
# 41      -9.186319      Pública               Non         Si
# ..            ...          ...               ...        ...
# 520     -8.463442      Pública               Non         Si
# 562     -8.292017      Pública               Non         Si
# 575     -8.582285      Pública               Non         Si
# 585     -9.037006      Pública               Non         Si
# 586     -8.376145      Pública               Non         Si
#
# [100 rows x 13 columns]

# %%
# Create a new Dataframe with all the language schools
eois = df[df['Tipo de centro'] == 'EOI']
eois
# Out:
#        Código                           Nome                    Enderezo  \
# 347  15023132                  EOI da Coruña        Rúa da Educación s/n
# 429  15026546                  EOI de Ferrol                 Rúa Real 29
# 524  15032194  EOI de Santiago de Compostela  Rúa Ulpiano Villanueva 1-2
#
#                    Concello Provincia  Cód. postal   Teléfono Tipo de centro  \
# 347                A Coruña  A Coruña        15011  981279100            EOI
# 429                  Ferrol  A Coruña        15402  981324025            EOI
# 524  Santiago de Compostela  A Coruña        15705  881867901            EOI
#
#      COORDENADA_X  COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 347     43.370686     -8.423161      Pública               Non         Si
# 429     43.485313     -8.229640      Pública               Non         Si
# 524     42.892800     -8.543636      Pública               Non         Si

# %%
# Create a new DataFrame with all the language schools (EOI) or Conservatories (CMUS)
eois = df[(df['Tipo de centro'] == 'EOI') | (df['Tipo de centro'] == 'CMUS')  ]
eois
# Out:
#        Código                                        Nome  \
# 347  15023132                               EOI da Coruña
# 427  15026492                     CMUS Superior da Coruña
# 429  15026546                               EOI de Ferrol
# 432  15026650                  CMUS Elemental de Betanzos
# 433  15026662                CMUS Profesional de Carballo
# 437  15026728               CMUS Profesional de Culleredo
# 439  15026741    CMUS Profesional das Pontes de G.Rodríg.
# 448  15027022      CMUS Profesional Federico Paz Carbajal
# 453  15027162                  CMUS Profesional de Melide
# 477  15027617                  CMUS Profesional Xan Viaño
# 514  15032078                   CMUS Profesional de Arzúa
# 524  15032194               EOI de Santiago de Compostela
# 525  15032200  CMUS Profesional de Ribeira Enrique Paisal
# 533  15032303                  CMUS Profesional da Coruña
# 541  15032418                CMUS Profesional de Santiago
#
#                              Enderezo                       Concello  \
# 347              Rúa da Educación s/n                       A Coruña
# 427            Rúa Manuel Murguía s/n                       A Coruña
# 429                       Rúa Real 29                         Ferrol
# 432                  Praza de Galicia                       Betanzos
# 433                    Rúa do Pan s/n                       Carballo
# 437              Avd.de la Coruña s/n                      Culleredo
# 439            Avenida das Veigas s/n  As Pontes de García Rodríguez
# 448        Rúa Frai Xosé Dos Santos 7                           Noia
# 453                   Rúa Galicia s/n                         Melide
# 477      Avenida DO MAR - CARANZA 2-4                         Ferrol
# 514             Rúa  Santiago, 160 00                          Arzúa
# 524        Rúa Ulpiano Villanueva 1-2         Santiago de Compostela
# 525  Rúa Miguel Rodriguez Bautista 21                        Ribeira
# 533        Praza DO CONSERVATORIO s/n                       A Coruña
# 541          Rúa Monte dos Postes s/n         Santiago de Compostela
#
#     Provincia  Cód. postal   Teléfono Tipo de centro  COORDENADA_X  \
# 347  A Coruña        15011  981279100            EOI     43.370686
# 427  A Coruña        15011  981141295           CMUS     43.368923
# 429  A Coruña        15402  981324025            EOI     43.485313
# 432  A Coruña        15300  981773696           CMUS     43.282352
# 433  A Coruña        15100  981704300           CMUS     43.211384
# 437  A Coruña        15670  981667798           CMUS     43.316315
# 439  A Coruña        15320  981440024           CMUS     43.450810
# 448  A Coruña        15200  981824885           CMUS     42.778710
# 453  A Coruña        15800  981507929           CMUS     42.916096
# 477  A Coruña        15406  981333317           CMUS     43.484650
# 514  A Coruña        15810  981500934           CMUS     42.928196
# 524  A Coruña        15705  881867901            EOI     42.892800
# 525  A Coruña        15960  981873204           CMUS     42.557198
# 533  A Coruña        15011  981276800           CMUS     43.370594
# 541  A Coruña        15703  981519845           CMUS     42.886610
#
#      COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 347     -8.423161      Pública               Non         Si
# 427     -8.423391      Pública               Non         Si
# 429     -8.229640      Pública               Non         Si
# 432     -8.211901      Pública               Non        Non
# 433     -8.695722      Pública               Non        Non
# 437     -8.365070      Pública               Non        Non
# 439     -7.862783      Pública               Non        Non
# 448     -8.891314      Pública               Non        Non
# 453     -8.014419      Pública               Non        Non
# 477     -8.210670      Pública               Non         Si
# 514     -8.168056      Pública               Non        Non
# 524     -8.543636      Pública               Non         Si
# 525     -8.994745      Pública               Non        Non
# 533     -8.422008      Pública               Non         Si
# 541     -8.532071      Pública               Non         Si

# %%
# Select and show all the IES in Santiago
df[(df['Tipo de centro'] == 'IES') & (df['Concello'] == 'Santiago de Compostela') ]
# Out:
#        Código                               Nome  \
# 232  15015743           IES Arcebispo Xelmírez I
# 233  15015755  IES Plurilingüe Rosalía de Castro
# 238  15015861                 IES Eduardo Pondal
# 300  15021482                   IES San Clemente
# 359  15023466                 IES Lamas de Abade
# 391  15025301          IES Arcebispo Xelmírez II
# 408  15025712        IES Antonio Fraguas Fraguas
# 440  15026753                 IES A Pontepedriña
# 450  15027058                    IES As Fontiñas
# 459  15027319                         IES de Sar
#
#                               Enderezo                Concello Provincia  \
# 232                Rúa Poza de Bar s/n  Santiago de Compostela  A Coruña
# 233                 Rúa San Clemente 3  Santiago de Compostela  A Coruña
# 238               Rúa Doctor Maceira 9  Santiago de Compostela  A Coruña
# 300               Rúa San Clemente s/n  Santiago de Compostela  A Coruña
# 359                       Rúa Raiola 8  Santiago de Compostela  A Coruña
# 391                  Rúa Irmandiños 15  Santiago de Compostela  A Coruña
# 408                     Rúa Londres 10  Santiago de Compostela  A Coruña
# 440   Rúa Amor Ruibal (A Pontepedriña)  Santiago de Compostela  A Coruña
# 450                    Rúa ESTOCOLMO 5  Santiago de Compostela  A Coruña
# 459  Rúa BERNARDO BARREIRO DE V.V. s/n  Santiago de Compostela  A Coruña
#
#      Cód. postal   Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y  \
# 232        15705  881866962            IES     42.878258     -8.552691
# 233        15705  881866556            IES     42.877575     -8.546718
# 238        15706  881866367            IES     42.871060     -8.554419
# 300        15705  881867501            IES     42.878563     -8.547453
# 359        15702  881866611            IES     42.854702     -8.524084
# 391        15704  881867055            IES     42.892900     -8.534361
# 408        15703  981588498            IES     42.881245     -8.530136
# 440        15702  881867152            IES     42.867850     -8.546486
# 450        15707  881866661            IES     42.886105     -8.523109
# 459        15702  881867162            IES     42.874470     -8.540165
#
#     TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 232      Pública               Non         Si
# 233      Pública               Non         Si
# 238      Pública               Non         Si
# 300      Pública               Non         Si
# 359      Pública               Non         Si
# 391      Pública               Non         Si
# 408      Pública               Non         Si
# 440      Pública               Non         Si
# 450      Pública               Non         Si
# 459      Pública               Non         Si

# %%
# Create a DataFrame with Name, Address and center type of all centers in Ferrol
centros_ferrol = df[df.Concello == 'Ferrol']
centros_ferrol = centros_ferrol[['Nome','Enderezo','Tipo de centro']]
# or directly
# centros_ferrol = df[df.Concello == 'Ferrol'][['Nome','Enderezo','Tipo de centro']]
centros_ferrol
# Out:
#                                                   Nome  \
# 104                      CPR Plurilingüe Jesús Maestro
# 105                           CPR Plurilingüe La Salle
# 106                                CPR Tirso de Molina
# 107                    CPR Plurilingüe Sagrado Corazón
# 108                  CPR Plurilingüe Compañía de María
# 109                         CPR Plurilingüe Cristo Rey
# 110           CPR Plurilingüe Santa Juana de Lestonnac
# 111                        CPR Plurilingüe San Rosendo
# 113                                          CPR Belén
# 114                                           CPR Ludy
# 115                            CEIP Cruceiro de Canido
# 116                                    IES de Catabois
# 117                           CEIP Plurilingüe Recimil
# 118                                CEE Terra de Ferrol
# 119                                 IES Sofía Casanova
# 120                              IES Concepción Arenal
# 121                                   CIFP Ferrolterra
# 122                          CIFP Rodolfo Ucha Piñeiro
# 123                              IES Saturnino Montojo
# 124                                   CEIP Isaac Peral
# 125                     CPR Plurilingüe Valle Inclán I
# 298                                         CIFP Leixa
# 299                                         IES Canido
# 316                                CEIP Manuel Masdías
# 317             CEIP Plurilingüe San Xoán de Filgueira
# 318            CEIP Almirante Juan de Lángara y Huarte
# 367                                      CEIP de Pazos
# 375                                    CEIP de Esteiro
# 376                            CEIP Plurilingüe A Laxe
# 393                                     CEEPR Aspanaes
# 398                                   IES Ferrol Vello
# 403                        IES Ricardo Carvalho Calero
# 410                        EPAPU Sta. María de Caranza
# 429                                      EOI de Ferrol
# 446                         CEIP Plurilingüe de Ponzos
# 477                         CMUS Profesional Xan Viaño
# 511                             ESCO Náutico-Pesqueira
# 572  Cen. Pub. Esc.Especialistas Estación Naval A G...
# 573         Cen. Pub. Esc.Especialistas Antonio Escaño
# 581                                      CPR Suso Añón
#
#                                  Enderezo Tipo de centro
# 104                  Rúa EMILIO ANTON N.9            CPR
# 105                   Rúa Pardo Bazan s/n            CPR
# 106                              Arce s/n            CPR
# 107               Estrada de Castilla 160            CPR
# 108                      Rúa SAN AMARO 18            CPR
# 109                     A Coruña, 35 - 37            CPR
# 110                 Rúa Nai Lestonnac s/n            CPR
# 111            Rúa Pintor Maximo Ramos 11            CPR
# 113                  Praza do Tronco, 1-3            CPR
# 114                    Rúa Rio Lambre 6-8            CPR
# 115                Cruceiro de Canido s/n           CEIP
# 116               Estrada de Catabois s/n            IES
# 117               Vivendas Protexidas s/n           CEIP
# 118                San Pedro de Leixa s/n            CEE
# 119                 Rúa O Galego Soto s/n            IES
# 120                        Rúa Cuntis s/n            IES
# 121             Avenida Ramón y Cajal s/n           CIFP
# 122        Avenida Castelao, 64 (Caranza)           CIFP
# 123                 Avenida Mac Mahon s/n            IES
# 124                 Avenida Mac Mahon s/n           CEIP
# 125            Estrada de Xoane n.170-172            CPR
# 298            Rúa SAN PEDRO DE LEIXA s/n           CIFP
# 299                    Rúa Navegantes s/n            IES
# 316          Rúa Cuco Ruiz, s/n (Caranza)           CEIP
# 317                 Rúa Campo de Chao s/n           CEIP
# 318            Estrada de Catabois, 45-71           CEIP
# 367               Serantes (San Salvador)           CEIP
# 375                       Avenida de Vigo           CEIP
# 376                    Rúa A Torre, Valón           CEIP
# 393                San Pedro de Leixa s/n          CEEPR
# 398  Rúa Alonso Lopez, s/n (Ferrol Vello)            IES
# 403                  Avenida Castelao s/n            IES
# 410             Rúa Luis de Requesens s/n          EPAPU
# 429                           Rúa Real 29            EOI
# 446                        Rúa Ponzos s/n           CEIP
# 477          Avenida DO MAR - CARANZA 2-4           CMUS
# 511           Avenida 19 de Febrero 30-34           ESCO
# 572    Rúa Estación Naval de la Graña s/n      Cen. Pub.
# 573                       Rúa Tejeras s/n      Cen. Pub.
# 581          Rúa Sánchez Calviño 48 Baixo            CPR

# %%
# select a row attending to its position
#centros_ferrol.iloc[0]
centros_ferrol.iloc[1]
# Out:
# Nome              CPR Plurilingüe La Salle
# Enderezo               Rúa Pardo Bazan s/n
# Tipo de centro                         CPR
# Name: 105, dtype: object

# %%
# select a row attending to its index
#centros_ferrol.loc[104]
centros_ferrol.loc[105]
# Out:
# Nome              CPR Plurilingüe La Salle
# Enderezo               Rúa Pardo Bazan s/n
# Tipo de centro                         CPR
# Name: 105, dtype: object

# %%
# Maybe it could be interesting to use center code as index
df = pd.read_excel(ficheiro,index_col='Código')
df.head()
# Out:
#                                  Nome                              Enderezo  \
# Código
# 15000016  CEIP Plurilingüe San Marcos                    Campo da Feira s/n
# 15000107                  CEIP A Maía      Rúa Peregrina, s/n (Bertamiráns)
# 15000132         CPR Plurilingüe Alca            Lugar Biduído de Arriba 36
# 15000338              CPI As Mirandas       Avenida Celso Emilio Ferreiro 4
# 15000363        CEIP Ponte dos Brozos  Avenida Arsenio Iglesias, 34 (Sabon)
#
#           Concello Provincia  Cód. postal   Teléfono Tipo de centro  \
# Código
# 15000016  Abegondo  A Coruña        15318  881880201           CEIP
# 15000107      Ames  A Coruña        15220  881866002           CEIP
# 15000132      Ames  A Coruña        15895  981531103            CPR
# 15000338      Ares  A Coruña        15624  881930020            CPI
# 15000363   Arteixo  A Coruña        15142  881960506           CEIP
#
#           COORDENADA_X  COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# Código
# 15000016     43.229183     -8.286580      Pública               Non         Si
# 15000107     42.867485     -8.657342      Pública               Non         Si
# 15000132     42.846325     -8.600729      Privada                Si        Non
# 15000338     43.429363     -8.246173      Pública               Non         Si
# 15000363     43.306940     -8.510333      Pública               Non         Si

# %%
# Select the first row
df.iloc[0]
#df.loc[15000016]
# Out:
# Nome                 CEIP Plurilingüe San Marcos
# Enderezo                      Campo da Feira s/n
# Concello                                Abegondo
# Provincia                               A Coruña
# Cód. postal                                15318
# Teléfono                               881880201
# Tipo de centro                              CEIP
# COORDENADA_X                           43.229183
# COORDENADA_Y                            -8.28658
# TITULARIDADE                             Pública
# ENSINO_CONCERTADO                            Non
# DEPENDENTE                                    Si
# Name: 15000016, dtype: object

# %%
# Select the four first rows
df.iloc[0:4]
# Out:
#                                  Nome                          Enderezo  \
# Código
# 15000016  CEIP Plurilingüe San Marcos                Campo da Feira s/n
# 15000107                  CEIP A Maía  Rúa Peregrina, s/n (Bertamiráns)
# 15000132         CPR Plurilingüe Alca        Lugar Biduído de Arriba 36
# 15000338              CPI As Mirandas   Avenida Celso Emilio Ferreiro 4
#
#           Concello Provincia  Cód. postal   Teléfono Tipo de centro  \
# Código
# 15000016  Abegondo  A Coruña        15318  881880201           CEIP
# 15000107      Ames  A Coruña        15220  881866002           CEIP
# 15000132      Ames  A Coruña        15895  981531103            CPR
# 15000338      Ares  A Coruña        15624  881930020            CPI
#
#           COORDENADA_X  COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# Código
# 15000016     43.229183     -8.286580      Pública               Non         Si
# 15000107     42.867485     -8.657342      Pública               Non         Si
# 15000132     42.846325     -8.600729      Privada                Si        Non
# 15000338     43.429363     -8.246173      Pública               Non         Si

# %%
# Select the last row
df.iloc[[-1]]
#df.tail(1)
# Out:
#                              Nome    Enderezo Concello Provincia  Cód. postal  \
# Código
# 15033231  EMUSPR Rockschoolcenter  Rúa Neda 2    Narón  A Coruña        15570
#
#          Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# Código
# 15033231      NaN         EMUSPR     43.490913     -8.201881      Privada
#
#          ENSINO_CONCERTADO DEPENDENTE
# Código
# 15033231               Non        Non

# %%
# Select the two last rows
df.iloc[-2:]
# Out:
#                              Nome                Enderezo  Concello Provincia  \
# Código
# 15033228        CEIP Novo Mesoiro  Rúa Fragas do Eume s/n  A Coruña  A Coruña
# 15033231  EMUSPR Rockschoolcenter              Rúa Neda 2     Narón  A Coruña
#
#           Cód. postal   Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y  \
# Código
# 15033228        15190  881961235           CEIP     43.324470     -8.439917
# 15033231        15570        NaN         EMUSPR     43.490913     -8.201881
#
#          TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# Código
# 15033228      Pública               Non         Si
# 15033231      Privada               Non        Non

# %%
# Select the center 15033204
# use the index

df.loc[[15033204]]
# Out:
#                              Nome                      Enderezo  Concello  \
# Código
# 15033204  CEDA Profesional Druida  Rúa Fernando Macías 26 Baixo  A Coruña
#
#          Provincia  Cód. postal Teléfono Tipo de centro  COORDENADA_X  \
# Código
# 15033204  A Coruña        15004      NaN           CEDA      43.36643
#
#           COORDENADA_Y TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# Código
# 15033204     -8.413181      Privada               Non        Non

# %%
# Select the next centers: 15033150, 15033162
df.loc[[15033150, 15033162]]
# Out:
#                                 Nome                  Enderezo  \
# Código
# 15033150    CPREX Semente Compostela        Rúa do Ceo 3 Baixo
# 15033162  ESMU Municipal de Negreira  Carreira de San Mauro 11
#
#                         Concello Provincia  Cód. postal Teléfono  \
# Código
# 15033150  Santiago de Compostela  A Coruña        15707      NaN
# 15033162                Negreira  A Coruña        15830      NaN
#
#          Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# Código
# 15033150          CPREX     42.890810     -8.529286      Privada
# 15033162           ESMU     42.909138     -8.736795      Pública
#
#          ENSINO_CONCERTADO DEPENDENTE
# Código
# 15033150               Non        Non
# 15033162               Non        Non

# %%
# Sometimes we choose to use loc and sometimes iloc
# loc <- traballa con index/labels
# iloc <- traballa con posicións

# %%
# Write a XLS file with CEIP centers
centros_ceip = df[df['Tipo de centro'] == 'CEIP']
#centros_ceip.head()
#centros_ceip.to_excel('output/ceip_ferrol.xls')
centros_ceip.to_excel('output/ceip_ferrol.xlsx')

# %%
# Give a name to the sheet
centros_ceip.to_excel('output/ceip_ferrol.xlsx',sheet_name='A Coruña')

# %%
# We must to select the sheet to work with during the open operation
ficheiro = '../datasets/centros_educativos_galicia.xls'
df_corunha = pd.read_excel(ficheiro,sheet_name='A Coruña')
df_lugo = pd.read_excel(ficheiro,sheet_name='Lugo')

# %%
df_corunha.sample()
#df_lugo.sample()
# Out:
#        Código             Nome  Enderezo              Concello Provincia  \
# 177  15013059  EEI de Vilariño  Vilariño  A Pobra do Caramiñal  A Coruña
#
#      Cód. postal   Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y  \
# 177        15940  636485076            EEI      42.59402     -8.933745
#
#     TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 177      Pública               Non         Si

# %%
# Concat dataframes (similar to concat Series)
df_total = pd.concat([df_corunha,df_lugo])
df_total
# Out:
#        Código                                      Nome  \
# 0    15000016               CEIP Plurilingüe San Marcos
# 1    15000107                               CEIP A Maía
# 2    15000132                      CPR Plurilingüe Alca
# 3    15000338                           CPI As Mirandas
# 4    15000363                     CEIP Ponte dos Brozos
# ..        ...                                       ...
# 220  27020975         EMUSPR Casa da Música de Chantada
# 221  27020987                                CAD Drocer
# 222  27020999                              CPR A Mariña
# 223  27021001  CPR Fundación Laboral de la Construcción
# 224  27601509                            EPAPU Albeiros
#
#                                  Enderezo  Concello Provincia  Cód. postal  \
# 0                      Campo da Feira s/n  Abegondo  A Coruña        15318
# 1        Rúa Peregrina, s/n (Bertamiráns)      Ames  A Coruña        15220
# 2              Lugar Biduído de Arriba 36      Ames  A Coruña        15895
# 3         Avenida Celso Emilio Ferreiro 4      Ares  A Coruña        15624
# 4    Avenida Arsenio Iglesias, 34 (Sabon)   Arteixo  A Coruña        15142
# ..                                    ...       ...       ...          ...
# 220                    Praza de Galicia 1  Chantada      Lugo        27500
# 221                        Calzada Xián 8      Lugo      Lugo        27003
# 222           Avenida Arcadio Pardiñas 44    Burela      Lugo        27880
# 223            Lugar San Xoán do Alto s/n      Lugo      Lugo        27232
# 224               Parque da Milagrosa s/n      Lugo      Lugo        27003
#
#       Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# 0    881880201           CEIP     43.229183     -8.286580      Pública
# 1    881866002           CEIP     42.867485     -8.657342      Pública
# 2    981531103            CPR     42.846325     -8.600729      Privada
# 3    881930020            CPI     43.429363     -8.246173      Pública
# 4    881960506           CEIP     43.306940     -8.510333      Pública
# ..         ...            ...           ...           ...          ...
# 220        NaN         EMUSPR      0.000000      0.000000      Privada
# 221        NaN            CAD     43.021520     -7.581664      Privada
# 222        NaN            CPR      0.000000      0.000000      Privada
# 223        NaN            CPR     42.984690     -7.590076      Privada
# 224  982828106          EPAPU     43.022408     -7.562322      Pública
#
#     ENSINO_CONCERTADO DEPENDENTE
# 0                 Non         Si
# 1                 Non         Si
# 2                  Si        Non
# 3                 Non         Si
# 4                 Non         Si
# ..                ...        ...
# 220               Non        Non
# 221               Non        Non
# 222               Non        Non
# 223               Non        Non
# 224               Non         Si
#
# [841 rows x 13 columns]

# %%
# Save CPR centers from the two provinces in an only file
# Only the next fields: Código, nome, enderezo, concello, provincia, código postal e teléfono
df_total[df_total['Tipo de centro'] == 'CPR'][['Código','Nome', 'Enderezo', 'Concello', 'Provincia', 'Cód. postal', 'Teléfono']].to_excel('output/centros_CPR.xlsx',sheet_name='CPR',index='Código')
