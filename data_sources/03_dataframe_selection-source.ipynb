# %% [markdown]
# # Pandas. Selecting rows and columns
#
# Pandas documentation: https://pandas.pydata.org/docs/index.html
#
# Pandas API reference: https://pandas.pydata.org/docs/reference/index.html#api

# %%
#import pandas library
import pandas as pd

# %% [markdown]
# ### Population in galician municipalities
#
# **Source**: Instituto Galego de Estatística
#
# https://www.ige.gal/

# %%
# Open CSV fil from local filesystem
df_concellos = pd.read_csv(('../datasets/concellos_con_poboacion.csv'))

# %%
df_concellos
# Out:
#                Concello  CODIGOINE  poboacion
# 0              Sarreaus      32078     1114.0
# 1             Taboadela      32079     1452.0
# 2               Bola, A      32014     1075.0
# 3                Maside      32045     2718.0
# 4             Trasmiras      32082     1261.0
# ..                  ...        ...        ...
# 308  Salvaterra de Miño      36050    10048.0
# 309            Sanxenxo      36051    17635.0
# 310             Silleda      36052     8845.0
# 311          Soutomaior      36053     7482.0
# 312    Cerdedo-Cotobade      36011        NaN
#
# [313 rows x 3 columns]

# %%
# Select columns: concello and poboacion
df_concellos[['Concello','poboacion']]
# Out:
#                Concello  poboacion
# 0              Sarreaus     1114.0
# 1             Taboadela     1452.0
# 2               Bola, A     1075.0
# 3                Maside     2718.0
# 4             Trasmiras     1261.0
# ..                  ...        ...
# 308  Salvaterra de Miño    10048.0
# 309            Sanxenxo    17635.0
# 310             Silleda     8845.0
# 311          Soutomaior     7482.0
# 312    Cerdedo-Cotobade        NaN
#
# [313 rows x 2 columns]

# %%
# Select columns: concello and CODIGOINE
df_concellos[['Concello','CODIGOINE']]
# Out:
#                Concello  CODIGOINE
# 0              Sarreaus      32078
# 1             Taboadela      32079
# 2               Bola, A      32014
# 3                Maside      32045
# 4             Trasmiras      32082
# ..                  ...        ...
# 308  Salvaterra de Miño      36050
# 309            Sanxenxo      36051
# 310             Silleda      36052
# 311          Soutomaior      36053
# 312    Cerdedo-Cotobade      36011
#
# [313 rows x 2 columns]

# %%
# Select 3 first rows
df_concellos.head(3)
# Out:
#     Concello  CODIGOINE  poboacion
# 0   Sarreaus      32078     1114.0
# 1  Taboadela      32079     1452.0
# 2    Bola, A      32014     1075.0

# %%
# Select the 2nd row
# Rows starts from 0
df_concellos.iloc[[1]]
# Out:
#     Concello  CODIGOINE  poboacion
# 1  Taboadela      32079     1452.0

# %%
# Select the 2nd row
# .loc uses the index to select rows
df_concellos.loc[[1]]
# Out:
#     Concello  CODIGOINE  poboacion
# 1  Taboadela      32079     1452.0

# %%
# Load the dataset again, using 'Concellos' as index
df_concellos2 = pd.read_csv(('../datasets/concellos_con_poboacion.csv'),index_col='Concello')

# %%
df_concellos2
# Out:
#                     CODIGOINE  poboacion
# Concello
# Sarreaus                32078     1114.0
# Taboadela               32079     1452.0
# Bola, A                 32014     1075.0
# Maside                  32045     2718.0
# Trasmiras               32082     1261.0
# ...                       ...        ...
# Salvaterra de Miño      36050    10048.0
# Sanxenxo                36051    17635.0
# Silleda                 36052     8845.0
# Soutomaior              36053     7482.0
# Cerdedo-Cotobade        36011        NaN
#
# [313 rows x 2 columns]

# %%
# Select the 2nd row
# Rows starts from 0
df_concellos2.iloc[[1]]
# Out:
#            CODIGOINE  poboacion
# Concello
# Taboadela      32079     1452.0

# %%
# Select the 2nd row
# .loc uses the index to select rows
df_concellos2.loc[[1]]     #fails, because '1' doesn't belong to the index range
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Select the 2nd row
#       2 # .loc uses the index to select rows
# ----> 3 df_concellos2.loc[[1]]     #fails, because '1' doesn't belong to the index range
#
# File ~/miniconda3/envs/clase/lib/python3.13/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/clase/lib/python3.13/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/miniconda3/envs/clase/lib/python3.13/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/miniconda3/envs/clase/lib/python3.13/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/miniconda3/envs/clase/lib/python3.13/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/clase/lib/python3.13/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([1], dtype='int64', name='Concello')] are in the [index]"

# %%
# Select the 2nd row  <<< 'Taboadela'
df_concellos2.loc[['Taboadela']]

# %%
# loc vs iloc

# when to use loc: 
# when you know the indexes and you need to find something concrete
# to select ranges omiting positions

# when to use iloc:
# when you want to select rows or ranges attending at the position in the dataset

# %%
df_concellos2

# %%
# Select many independent rows using iloc
df_concellos2.iloc[[1,3,5]]

# %%
# Select many independent rows using indexes with loc
df_concellos2.loc[['Taboadela','Maside','Carballeda de Avia']]

# %%
# Select a range of rows
df_concellos2.iloc[0:5]

# %%
# Select cell [row,column] 
df_concellos2.iloc[0,1]
